# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('./Dataset/data.csv')
df
# Out:
#     Age  Experience  Rank Nationality   Go
# 0    36          10     9          UK   NO
# 1    42          12     4         USA   NO
# 2    23           4     6           N   NO
# 3    52           4     4         USA   NO
# 4    43          21     8         USA  YES
# 5    44          14     5          UK   NO
# 6    66           3     7           N  YES
# 7    35          14     9          UK  YES
# 8    52          13     7           N  YES
# 9    35           5     9           N  YES
# 10   24           3     5         USA   NO
# 11   18           3     7          UK  YES
# 12   45           9     9          UK  YES

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Nationality']=le.fit_transform(df['Nationality'])
df['Go']=le.fit_transform(df['Go'])
df
# Out:
#     Age  Experience  Rank  Nationality  Go
# 0    36          10     9            1   0
# 1    42          12     4            2   0
# 2    23           4     6            0   0
# 3    52           4     4            2   0
# 4    43          21     8            2   1
# 5    44          14     5            1   0
# 6    66           3     7            0   1
# 7    35          14     9            1   1
# 8    52          13     7            0   1
# 9    35           5     9            0   1
# 10   24           3     5            2   0
# 11   18           3     7            1   1
# 12   45           9     9            1   1

# %%
x=df.drop('Go',axis=1)
y=df['Go']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y)

# %%
clf=DecisionTreeClassifier()
clf.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
yhat=clf.predict(xtest)
xtest
# Out:
#    Age  Experience  Rank  Nationality
# 7   35          14     9            1
# 0   36          10     9            1
# 1   42          12     4            2
# 6   66           3     7            0

# %%
plt.figure(figsize=(50,50))
plot_tree(clf,filled=True,fontsize=16)
# Out:
# [Text(1395.0, 2038.5, 'X[2] <= 6.5\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(697.5, 679.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(2092.5, 679.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]')]

# %%
print("R2_score :",r2_score(ytest,yhat))
print("MSE :",mean_squared_error(ytest,yhat))
print("MAE :",mean_absolute_error(ytest,yhat))
# Out:
# R2_score : 0.0
# MSE : 0.25
# MAE : 0.25

# %%
clf=DecisionTreeClassifier()
clf.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
# encoded usa as 2
data={'Age':[40],"Experience":[10],"Rank":[7],"Nationality":[2]}
ip=pd.DataFrame(data)
op=clf.predict(ip)
op
#op=0 is don't go
#op=1 is go
# Out:
# array([0])
